# %%
from google.colab import drive
drive.mount('/content/drive')

CHECKPOINT_DIR = '/content/drive/MyDrive/GameForge3D/checkpoints'
print(f"Checkpoint directory set to: {CHECKPOINT_DIR}")

# %%
# !pip install torch torchvision transformers diffusers open3d pymeshlab trimesh reportlab qrcode fastapi uvicorn datasets

# %% [markdown]
# ### Next Steps
# - Register for a ShapeNet academic account.
# - Download Cap3D via HuggingFace datasets.
